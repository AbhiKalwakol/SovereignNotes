# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhiKalwakol/SovereignNotes/blob/main/SovereignNotes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git config --global user.email "GH_EMAIL"
# !git config --global user.name "GH_UNAME"

# %%
from google.colab import userdata
import os

# This pulls the token from the "Secrets" tab safely
my_secret_token = userdata.get('GH_TOKEN')
my_username = userdata.get('GH_UNAME')

# Now you can use it to clone your repo
REPO_URL = f"https://{my_secret_token}@github.com/{my_username}/SovereignNotes.git"
# !git clone {REPO_URL}
# Out:
# Cloning into 'SovereignNotes'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 8 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (8/8), 4.29 KiB | 488.00 KiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "xformers<0.0.29" "trl<0.9.0" peft accelerate bitsandbytes
# Out:
# ...
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-fxr8krt3/unsloth_964ea1ffabde4c50ac62f22dbb1d01db
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-fxr8krt3/unsloth_964ea1ffabde4c50ac62f22dbb1d01db
#   Resolved https://github.com/unslothai/unsloth.git to commit 9a551831ef2eff33f947cc1a7e1b259f9913950b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 19.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 51.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 117.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.8/393.8 kB 44.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 120.0 MB/s eta 0:00:00
# ...

# %%
from unsloth import FastLanguageModel
import torch

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Qwen2.5-VL-7B-Instruct-bnb-4bit",
    max_seq_length = 2048, # Increase this if your files are very long
    load_in_4bit = True,
)

FastLanguageModel.for_inference(model) # Enable native inference speedups
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2026.3.3: Fast Qwen2_5_Vl patching. Transformers: 5.2.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/6.90G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/729 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/791 [00:00<?, ?B/s]
# chat_template.json: 0.00B [00:00, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
